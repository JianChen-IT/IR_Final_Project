# %%
from search_engine.search_engine import SearchEngine
import networkx as nx
from networkx import Graph
from sklearn.model_selection import train_test_split
import implicit
import scipy.sparse as sparse
from scipy.sparse import csr_matrix
from fast_pagerank import pagerank
from fast_pagerank import pagerank_power
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
import os
import math
import warnings
import csv
warnings.filterwarnings('ignore')

# %%
search_engine = SearchEngine()
# Out:
# What ranking mode do you want?
# 1. TF-IDF
# 2. WORD2VEC
# 1

# %%
search_engine.tweets.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10000 entries, 0 to 9999
# Data columns (total 20 columns):
# created_at                 10000 non-null object
# id_str                     10000 non-null object
# text                       10000 non-null object
# source                     10000 non-null object
# truncated                  10000 non-null bool
# in_reply_to_screen_name    1496 non-null object
# user                       10000 non-null object
# reply_count                10000 non-null int64
# retweet_count              10000 non-null int64
# favorite_count             10000 non-null int64
# entities                   10000 non-null object
# favorited                  10000 non-null bool
# retweeted                  10000 non-null bool
# filter_level               10000 non-null object
# timestamp_ms               10000 non-null object
# retweeted_status           6814 non-null object
# extended_tweet             1289 non-null object
# extended_entities          323 non-null object
# withheld_in_countries      2 non-null object
# original_text              10000 non-null object
# dtypes: bool(3), int64(3), object(14)
# memory usage: 1.3+ MB

# %%
#u -> search_engine.tweets.user[0]['screen_name']
#v -> search_engine.tweets.retweeted_status[1]['user']['screen_name']

# %%
#Para Poner bonito -> dictionario de los usuarios v
#Mirar página en favoritos, lo del color también en la NS_P09
#Add weight edges from how many times user u retweeted user v
g = nx.Graph()
for tweet in search_engine.tweets.iterrows():
    if str(tweet[1]['retweeted_status'])!='nan':
        u=tweet[1]['user']['screen_name']
        v=tweet[1]['retweeted_status']['user']['screen_name']
        g.add_node(u)
        g.add_node(v)
        g.add_edge(u,v)

# %%
pos=nx.spring_layout(g)
plt.figure(figsize=(15,15))
nx.draw_networkx(g, pos, node_shape='o', node_size=50, with_labels=False, font_weight='bold')
plt.show()

# %%
#Recomender System
# -ALS -> No se que hacer con test

# %%
train, test = train_test_split(list(g.edges), test_size = .2 ,random_state = 1) #559 - 140

# %% [markdown]
# ALS (Alternate Least Squares) #VER SI SON LOS FRIENDS-OF-FRIENDS

# %% [markdown]
# Version 1

# %%
def adjency_matrix(vocabulary: dict, edges: list) -> csr_matrix:
    adj_matrix=pd.DataFrame(0, columns=list(vocabulary.values()), index=list(vocabulary.values()))
    A=np.array(edges)
    for i in range(len(A)):
        A[i][0]=vocabulary[A[i][0]]
        A[i][1]=vocabulary[A[i][1]]
    for i in range(len(A)):
        useru=int(A[i][0])
        userv=int(A[i][1])
        adj_matrix[useru][userv]=1
        adj_matrix[userv][useru]=1
        adj_matrix_sparse=sparse.csr_matrix(adj_matrix.values)
    return adj_matrix_sparse

def similar_users(user_id: int, top: int, vocabulary:dict) -> list:
    ALS_similar_users=model.similar_users(user_id,top)
    ALS_similar_users_with_names=number_to_username(ALS_similar_users, vocabulary)
    return ALS_similar_users_with_names

def recommend_users(user_id: int, G:csr_matrix, top: int, vocabulary:dict) -> list:
    ALS_recommended_users=model.recommend(user_id, G, top)
    ALS_recommended_users_with_names=number_to_username(ALS_recommended_users, vocabulary)
    return ALS_recommended_users_with_names

def number_to_username(ALS_list: list, vocabulary: dict) -> list:
    ALS_list_transformed=[]
    for i in range(len(ALS_list)):
        name=list(vocabulary.keys())[list(vocabulary.values()).index(ALS_list[i][0])]
        new_tuple=(name, ALS_list[i][1])
        ALS_list_transformed.append(new_tuple)
    return ALS_list_transformed

def predict_ALS(testset, model):
    """
    predict for a list of observations the score for adding/removing a link
    """

    # initialize the empty list
    all_predictions = []

    # scroll the obs
    for n1,n2, w in testset:
        
        # take here the low-dimensional vectors returned by the matrix factorization
        
        array_n1 = model.user_factors[n1,:]
        array_n2 = model.item_factors[n2,:]

        # multiplying these vectors we generate an approximation for the edge score
        one_p = np.dot(array_n1, array_n2)

        all_predictions.append(one_p)
        
    return all_predictions

# %%
vocabulary = {}
for d in list(g.edges):
    for term in d:
        index = vocabulary.setdefault(term, int(len(vocabulary)))
        
G=adjency_matrix(vocabulary, train)

# %%
model = implicit.als.AlternatingLeastSquares(factors=10, iterations=5, calculate_training_loss=True)

#alpha_val = 40
#data_conf = (G * alpha_val).astype('double')

#model.fit(data_conf)
model.fit(G)
# Out:
# WARNING:root:Intel MKL BLAS detected. Its highly recommend to set the environment variable 'export MKL_NUM_THREADS=1' to disable its internal multithreading
# HBox(children=(FloatProgress(value=0.0, max=5.0), HTML(value='')))

# %%
A=np.array(test)
for i in range(len(A)):
    A[i][0]=int(vocabulary[A[i][0]])
    A[i][1]=int(vocabulary[A[i][1]])

df=pd.DataFrame(columns=['n1', 'n2', 'edge'])
df['n1']=A[:,0]
df['n2']=A[:,1]
df['edge']=np.ones(len(A))
df['n1']=df['n1'].astype(int)
df['n2']=df['n2'].astype(int)
df['edge']=df['edge'].astype(int)

df['rating']=predict_ALS(df.values, model)
df#.query("rating>0")
# Out:
#         n1    n2  edge        rating
# 0     2069  3115     1  0.000000e+00
# 1     5023  5024     1  0.000000e+00
# 2     1804  1805     1  0.000000e+00
# 3      887   888     1  0.000000e+00
# 4     6091  6092     1  0.000000e+00
# 5     6223  6224     1  0.000000e+00
# 6     6892  6893     1  0.000000e+00
# 7     4762  4764     1  0.000000e+00
# 8     2539  2540     1  0.000000e+00
# 9     3444  3536     1  0.000000e+00
# 10    2710  7488     1  0.000000e+00
# 11    1193  1195     1  0.000000e+00
# 12    3675  3676     1  0.000000e+00
# 13    3873  3874     1  0.000000e+00
# 14    4798  4803     1  0.000000e+00
# 15    2391  2412     1  0.000000e+00
# 16    1107  1112     1  0.000000e+00
# 17    6241  6246     1  0.000000e+00
# 18     337   529     1  0.000000e+00
# 19    7205  7205     1  0.000000e+00
# 20    2381  2382     1  0.000000e+00
# 21    5967  5974     1  0.000000e+00
# 22    1870  1874     1  0.000000e+00
# 23    1107  1156     1  0.000000e+00
# 24    3045  3048     1  0.000000e+00
# 25     337   376     1  0.000000e+00
# 26    6025  6026     1  0.000000e+00
# 27    5820  5821     1  0.000000e+00
# 28    3662  3663     1  0.000000e+00
# 29    3268  1373     1  1.017982e-05
# ...    ...   ...   ...           ...
# 1301  4830   991     1  0.000000e+00
# 1302   337   812     1  0.000000e+00
# 1303  3565  2514     1 -3.035630e-06
# 1304  3810  3817     1  0.000000e+00
# 1305  3064  3751     1  0.000000e+00
# 1306  1950  1951     1  0.000000e+00
# 1307  3368  3378     1  0.000000e+00
# 1308  1647  1662     1  0.000000e+00
# 1309  2144  4295     1  0.000000e+00
# 1310  2144  4343     1 -4.408429e-07
# 1311   337   780     1  0.000000e+00
# 1312  5036  6754     1  0.000000e+00
# 1313  2340  4073     1  0.000000e+00
# 1314   337   359     1  0.000000e+00
# 1315   337   611     1  0.000000e+00
# 1316  3639  3640     1  1.413381e-09
# 1317  2340  4090     1  0.000000e+00
# 1318  2307  2308     1  0.000000e+00
# 1319  4730  4731     1  0.000000e+00
# 1320   180   225     1  0.000000e+00
# 1321  1275  6635     1  0.000000e+00
# 1322  5967  5975     1  0.000000e+00
# 1323  7358  7358     1  0.000000e+00
# 1324  6617  6618     1  0.000000e+00
# 1325  2755  2785     1  0.000000e+00
# 1326  6470  6471     1  0.000000e+00
# 1327  2144  4283     1  0.000000e+00
# 1328  6429  6432     1  0.000000e+00
# 1329  4434  4440     1  0.000000e+00
# 1330   106   116     1  0.000000e+00
#
# [1331 rows x 4 columns]

# %%
#('gkb59', 'DoYouEvenLif')
#user_id=vocabulary['gkb59']
#top_n_user_similars=10

#ALS_sim_users=similar_users(user_id, top_n_user_similars, vocabulary)
#ALS_recom_users=recommend_users(user_id, G, top_n_user_similars, vocabulary)
#print(ALS_sim_users)
#print()
#print(ALS_recom_users)
#model.rank_items(user_id, G, list(vocabulary.values()))
#help(model.rank_items)

# %%
#a=adjency_matrix(vocabulary, train)

# %%
#model.recommend(user_id)

# %% [markdown]
# Adamic-Adar

# %%
def get_neighbors(username: str, usersu: list, usersv: list) -> list:
    neighbors=[]
    for i in range(len(usersu)):
        if (username==usersu[i]):
            neighbors.append(usersv[i])
        if (username==usersv[i]):
            neighbors.append(usersu[i])
    return neighbors

def get_recommendation_AA(username: str, usersu: list, usersv: list) -> pd.DataFrame:
    users_unique_list=set(usersu)|set(usersv)
    adamic_avar_data=pd.DataFrame(columns=[username], index=users_unique_list)
    for user_y in users_unique_list:
        if username!=user_y:
            x_neighbors=set(get_neighbors(username, usersu, usersv))
            y_neighbors=set(get_neighbors(user_y, usersu, usersv))
        same_neighbors=x_neighbors&y_neighbors
        aa_val=0
        for n in same_neighbors:
            num_neighbors=len(get_neighbors(n, usersu, usersv))
            aa_val+=(1/math.log(num_neighbors))
        adamic_avar_data[username][user_y]=aa_val
    top_n_recommendations_aa=adamic_avar_data[username].sort_values(ascending=False)
    aa_final_recommendation=pd.DataFrame(top_n_recommendations_aa)
    return aa_final_recommendation.head(10)

# %%
users_u=[names[0] for names in list(g.edges)]
users_v=[names[1] for names in list(g.edges)]
#Introduce a username to get its friends recommendations
u='1Krohmer13'
get_recommendation_AA(u, users_u, users_v)

# %% [markdown]
# PageRank

# %%
#Copy list(g.edges) -> con vocabulary transform to numbers

# %%
users_unique_list=list(vocabulary.keys())

A=np.array(g.edges)
for i in range(len(A)):
    for j in range(len(A[i])):
        A[i][j]=vocabulary[A[i][j]]

weights=np.ones(len(A))
shape=len(users_unique_list)
G = sparse.csr_matrix((weights, (A[:,0], A[:,1])), shape=(shape,shape))
pr=pagerank(G, p=0.85, reverse=True) #This will give the values of the users normalized
pr=[i * shape for i in pr]

# %%
color_map=[]
values=[]
for i in range(len(pr)):
    if pr[i]>10:
        name=list(vocabulary.keys())[list(vocabulary.values()).index(i)]
        values.append(name)

# %%
pos=nx.spring_layout(g)
plt.figure(figsize=(15,15))
#nx.draw_networkx(g, pos, node_shape='o', node_size=50, with_labels=False, font_weight='bold', node_colors=[('red' if (str(u)==str(name)) else 'black') for u in g.nodes()])
nx.draw_networkx(g, pos, node_shape='o', node_size=[1000 if (u in values) else 50 for u in g.nodes], with_labels=False, font_weight='bold', node_color=['red' if (u in values) else 'blue' for u in g.nodes])
plt.show()

# %%
help(nx.pagerank(g, alpha=0.85)
